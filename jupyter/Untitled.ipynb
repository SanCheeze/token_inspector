# %%
import pandas as pd

# %%
with open('related_wallets (8).txt') as file:
    text = file.readlines()

result = []
for line in text:
    wallet, count = line.split(': ')
    result.append({'wallet': wallet, 'count': int(count)})

df = pd.DataFrame(result)

# %%
df['count'].value_counts()
# Out:
# count
# 2     3663
# 3      862
# 4      325
# 5      126
# 6       87
# 7       49
# 8       25
# 9       17
# 12      13
# 10      12
# 14       8
# 11       5
# 13       5
# Name: count, dtype: int64

# %%
wallets = df[df['count'] >= 7]['wallet'].to_list()

# %%
with open('output.txt', 'w') as file:
    file.write('\n'.join(wallets))

# %%
with open('wallets_to_check.txt', 'r') as file:
    wallets = file.readlines()

# %%
for wallet in list(set([wallet.strip('\n') for wallet in wallets])):
    print(wallet)
# Out:
# 6BwHpQr5iCBSqW5g37GS9sbCG4vrGpLe14ZhxrvWpump
# 45HorE386uyiNioPfVoafVSZi1uejFDJEEpZgsHZpump
# CE9yq1EBNBbMcaaFsvyYUKVej8URCfTbqGS4Wa73pump
# 8yqfSBywC2w7pEXZW59V73W2z2EpbkCc9NiVjU15pump
# JDchttJaEu2aPnfmC1HjSoCPk677NNktTpcjAsgupump
# 9jMUqhiCChc2qTAqiZgBsrdtzKKapJVUgNZ5Qc9Gpump
# C1hPYPmrD8aJ3WrX4s1w8Nk2nCmpUAsPZFz43iripump
# 9SRF5kFNzY9niXVqwGixFiUBQHDdLvjLhvubNbyKpump
# 2PDykisEwm8r5ckW9HzKxiuRf8T1XJkgBZgZRr5mpump
# Fk6eEhRWJMtK3QxUgwZ47sVUFnWpCqrB4zwUGGAfpump
# 5FXBpGtQ5nkp8PFbaaEEWe2pffXHpkHzua2TrC4bpump
# AWUdHN6uvPsKqsXBxis3bkVHEEa1xCmVUQZNhU2Vpump
# DX6eFSDuEamyo8YNNpQ2YXeGBcJ5XUrw5DWeisJfpump
# F98s1LQ2ys58wgXZyyBPvzzEmNG2ek8tKmNnwNkcpump

# %%
# !pip install pandas asyncpg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import json
import asyncio
import pandas as pd
import asyncpg


async def load_tokens_df_from_dsn(dsn: str = "postgres://defi:2fe!!.iufh_=153fds1s4@localhost:5432/defi_db") -> pd.DataFrame:
    conn = await asyncpg.connect(dsn)
    try:
        rows = await conn.fetch("SELECT * FROM tokens;")
    finally:
        await conn.close()

    if not rows:
        return pd.DataFrame()

    return pd.DataFrame([dict(r) for r in rows])

# %%
tokens_df = await load_tokens_df_from_dsn()

# %%
tokens_df
# Out:
#     id                                         token  \
# 0    1  DYMdq7VqwJM82KTJaHUQcbSHtevmGW5Bi8Un3De1pump
# 1    3  6oA4pbQbL1BbcoVeXbwDcEX5JdvjMC95SGiDKPpjpump
# 2    5  CuqKjdvH5dUSA97VB5VZUtJPHQSzVt3L3cN9QfE5pump
# 3    7  HJXHpFsDDbVvB1HxPQRrKqvfNkoesfiU2kVnKS1qpump
# 4    9  8boYdoYNByXCPmJ3Ft6kgMNgKEoBQL5ktPi6hkRDpump
# 5   11  BvZbQ9Siw2FyTZUk1JVHX9whNBSjgN19Nd2fT9dKpump
# 6   13  CNSPsV6L7MHcd2Gbk4XDiHZ8MzshMuFp1pjv123apump
# 7   15  5ohLLEvyniETAy3zfTY4VRtLQ7NjW59oN1pePEdhpump
# 8   17  HpYGk2vkrqGh1SD5UUdb4EjEU5QdV6yBnN2tRH6Rpump
# 9   19  HpBFnqL47fmaWVNMn71gfydx7pMsZ6x82WyiV2Aepump
# 10  21  A6gdEndXYKqkQxE5Bst1JaNmqHgeHLtEAmwqaH3upump
# 11  23  2i97dvQwkCygyx7SJE9gaqZfHEVRViCrpstXqAifpump
# 12  25   AxKTVfFkWFvhMTpwFSE9vUg6wKZoPDcW1XdtkfKpump
# 13  27  HyeWA8KTCK6G8RBsyCNA5uDgGzwpZwk1gA5W4XRypump
# 14  29   sw9eqeivoruPfciUKsWAmdtXmhSz9jjcs9TkzZwpump
# 15  31  9RBpBHzjqr27aVPE4T7YPJrVS5EHzGsAWd33JejUpump
# 16  33  GYRsbdMFRHnpCKwzZaP7LTBvCUsJ9aV74gpjubnQpump
# ...

# %%
json.loads(tokens_df.iloc[0]['trades'])[0]
# Out:
# {'ts': 1768566529,
#  'from': 'N5sCnVNZuWzwayBm9evJv8gsrYxqj9MdCjxALRe4u95',
#  'value': 0.3584,
#  'action': 'ACTIVITY_TOKEN_SWAP',
#  'token1': '6BwHpQr5iCBSqW5g37GS9sbCG4vrGpLe14ZhxrvWpump',
#  'token2': 'So11111111111111111111111111111111111111112',
#  'amount1': 131691089908,
#  'amount2': 2493510,
#  'sources': 'pAMMBay6oceH9fJKBRHGP5D4bD4sWpmSwMn52FMfXEA|s7SunwrPG5SbViEKiViaDThPRJxkkTrNx2iRPN3exNC',
#  'platforms': 's7SunwrPG5SbViEKiViaDThPRJxkkTrNx2iRPN3exNC',
#  'signature': '42WGqfxs4mYD64CarCTvtGNm7vsmP5qiKrJNPqa4swHdRBF73t7JEMYAwW24vSJsPwrTdykjz2di3QJ8Rnr1fZS9',
#  'token1_decimals': 6,
#  'token2_decimals': 9}

# %%
trade = {
    'ts': 1768566529,
    'from': 'N5sCnVNZuWzwayBm9evJv8gsrYxqj9MdCjxALRe4u95',
    'value': 0.3584,
    'action': 'ACTIVITY_TOKEN_SWAP',
    'token1': '6BwHpQr5iCBSqW5g37GS9sbCG4vrGpLe14ZhxrvWpump',
    'token2': 'So11111111111111111111111111111111111111112',
    'amount1': 131691089908,
    'amount2': 2493510,
    'sources': 'pAMMBay6oceH9fJKBRHGP5D4bD4sWpmSwMn52FMfXEA|s7SunwrPG5SbViEKiViaDThPRJxkkTrNx2iRPN3exNC',
    'platforms': 's7SunwrPG5SbViEKiViaDThPRJxkkTrNx2iRPN3exNC',
    'signature': '42WGqfxs4mYD64CarCTvtGNm7vsmP5qiKrJNPqa4swHdRBF73t7JEMYAwW24vSJsPwrTdykjz2di3QJ8Rnr1fZS9',
    'token1_decimals': 6,
    'token2_decimals': 9
}

current_supply = 999952260.665739
token_value = trade["amount1"] # применить точность trade["token1_decimals"]
sol_value = trade["amount2"]  # применить точность trade["token2_decimals"]
usd_value = trade["value"]

sol_price = sol_value / token_value
usd_price = usd_value / token_value

sol_mcp = sol_price * current_supply
usd_mcp = usd_price * current_supply

# %%
usd_price * current_supply
# Out:
# 2721.3905699540405

# %%
import pandas as pd

df = pd.read_parquet("ml/data/dataset.parquet", engine="fastparquet")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   f_trades_total                 0 non-null      int32
#  1   f_trades_buy                   0 non-null      int32
#  2   f_trades_sell                  0 non-null      int32
#  3   f_buy_sell_ratio               0 non-null      int32
#  4   f_volume_total_usd             0 non-null      int32
#  5   f_volume_buy_usd               0 non-null      int32
#  6   f_volume_sell_usd              0 non-null      int32
#  7   f_net_flow_usd                 0 non-null      int32
#  8   f_avg_trade_usd                0 non-null      int32
#  9   f_median_trade_usd             0 non-null      int32
#  10  f_max_trade_usd                0 non-null      int32
#  11  f_unique_wallets               0 non-null      int32
#  12  f_top1_wallet_vol_share        0 non-null      int32
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [f_trades_total, f_trades_buy, f_trades_sell, f_buy_sell_ratio, f_volume_total_usd, f_volume_buy_usd, f_volume_sell_usd, f_net_flow_usd, f_avg_trade_usd, f_median_trade_usd, f_max_trade_usd, f_unique_wallets, f_top1_wallet_vol_share, f_top3_wallet_vol_share, f_wallet_vol_gini, f_time_to_first_trade_sec, f_time_to_10_trades_sec, f_time_to_100usd_sec, f_time_to_1000usd_sec, f_trades_per_min, f_volume_per_min, f_volume_accel, f_platforms_count, f_top_platform_share, f_has_aggregator_route, f_bundle_wallets_participated, f_bundle_participation_ratio, f_bundle_volume_share, f_bundle_net_flow_usd, f_bundle_first_entry_sec, f_bundle_entry_std_sec, target_log_mcap]
# Index: []
#
# [0 rows x 32 columns]
