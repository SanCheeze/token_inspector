# %%
import pandas as pd

# %%
with open('related_wallets (8).txt') as file:
    text = file.readlines()

result = []
for line in text:
    wallet, count = line.split(': ')
    result.append({'wallet': wallet, 'count': count})
